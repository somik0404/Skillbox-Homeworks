# %% [markdown]
# # Исключения
# ## Домашняя работа

# %% [markdown]
# ### Вопросы по лекциям.

# %% [markdown]
# Как поймать вообще все ошибки, которые могут произойти?

# %% [markdown]
# **Ответ:** except:

# %% [markdown]
# Сколько раз подряд можно указывать except?

# %% [markdown]
# **Ответ:** сколько угодно

# %% [markdown]
# Вы хотите с помощью print вывести название ошибки в консоль, как это сделать?

# %% [markdown]
# **Ответ:**

# %%
a = input()
b = input()
try:
    z = a * b
except Exception as exc:
    print(f"название ошибки - {exc}")

# %% [markdown]
# Вы хотите с помощью print вывести параметры ошибки в консоль, как это сделать?

# %% [markdown]
# **Ответ:**

# %%
a = input()
b = input()
try:
    z = a * b
except Exception as exc:
    print(f"параметры ошибки {exc.args}")
# Out:
# 4
# g
# параметры ошибки ("can't multiply sequence by non-int of type 'str'",)

# %% [markdown]
# Что такое DeprecationWarning?

# %% [markdown]
# **Ответ:** предупреждение, что это функцию уберут в следущей версии библиотеки

# %% [markdown]
# ### Разминочные задания.
# <br>
#
# Вам даны две функции. Поисследуйте, какие ошибки могут возникнуть при их реализации. Обработайте эти ошибки.

# %%
def div():
    try:
        for i in range(2):
            x = int(input("enter a number: "))
            y = int(input("enter another number: "))
            print(x, '/', y, '=', x / y)
    except ValueError as exc:
        print("деление невозможно т.к число нельзя преобразовать к целому")
        div()
div()

# %%
def sumOfPairs(L1, L2):
    try:
        if type(L1) == str or type(L2) == str:
            raise TypeError
        sumOfPairs = []
        for i in range(len(L1)):
            sumOfPairs.append(L1[i]+L2[i])
        return ("sumOfPairs =", sumOfPairs)
    except TypeError:
        print("не верный тип данных")

# %%
L1 = [2, 4, 6]
L2 = [1, 4, 5, 8]
sumOfPairs(L1, L2)
# Out:
# ('sumOfPairs =', [3, 8, 11])

# %% [markdown]
# ### Задание 1.
#
# Есть файл с протоколом регистраций пользователей на сайте (registrations.txt).<br>
# Каждая строка содержит информацию о имени, электронной почте и возрасте человека. <br><br>
#
#
# Надо проверить данные из файла, для каждой строки:
#  - присутсвуют все три поля
#  - поле имени содержит только буквы
#  - поле email содержит @ и .
#  - поле возраст является числом от 10 до 99<br>
#
# В результате проверки нужно сформировать два файла
#  - registrations_good.log для правильных данных, записывать строки как есть
# - registrations_bad.log для ошибочных, записывать строку и вид ошибки.<br>
#
# Для валидации строки данных написать метод, который может выкидывать исключения:
#  - НЕ присутсвуют все три поля: ValueError
#  - поле имени содержит НЕ только буквы: NotNameError (кастомное исключение)
#  - поле email НЕ содержит @ и .(точку): NotEmailError (кастомное исключение)
#  - поле возраст НЕ является числом от 10 до 99: ValueError
# Вызов метода обернуть в try-except.

# %%
class NotNameError(Exception):
    def __str__(self):
        return "Имя не подходит"


class NotEmailError(Exception):
    def __str__(self):
        return "Почта не подходит"


def namecheck(x):
    if not x.isalpha():
        raise NotNameError


def emailchek(y):
    if "@" not in str(y):
        raise NotEmailError
    if "." not in str(y):
        raise NotEmailError


def recording(line):
    try:
        linearray = line.split(" ")
        if len(linearray) != 3:
            raise ValueError
        else:
            name, email, age = line.split(" ")
        namecheck(name)
        emailchek(email)
        if 10 <= int(age) <= 100:
            f.write(line + "\n")
        else:
            print("возраст не подходит")
            raise ValueError
    except ValueError:
        print("Не достаточно аргументов")
        badlogs.write(f"ValueError - {line}" + "\n")
        return None
    except NotNameError as exc2:
        print("Имя не подходит")
        badlogs.write(f"ошибка - {exc2} в строке - {line}" + "\n")
        return None
    except NotEmailError as exc3:
        print("Не верный почтовый адрес")
        badlogs.write(f"ошибка - {exc3} в строке - {line}" + "\n")
        return None


with open("registrations_.txt", "r", encoding="utf-8") as ff, open("registrations_good.log.txt", "w",
                                                                   encoding="utf-8") as f, \
        open("registrations_bad.log.txt", "w", encoding="utf-8") as badlogs:
    for line in ff:
        line = line[:-1]
        recording(line)
# Out:
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не достаточно аргументов
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Имя не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# Не верный почтовый адрес
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Не достаточно аргументов
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Не достаточно аргументов
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Имя не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Не достаточно аргументов
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не достаточно аргументов
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Имя не подходит
# Не достаточно аргументов
# Имя не подходит
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не достаточно аргументов
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Не достаточно аргументов
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Не достаточно аргументов
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# Не достаточно аргументов
# Имя не подходит
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Не достаточно аргументов
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не верный почтовый адрес
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не достаточно аргументов
# Не достаточно аргументов
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Не достаточно аргументов
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не верный почтовый адрес
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Имя не подходит
# Не достаточно аргументов
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Не достаточно аргументов
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# Не верный почтовый адрес
# возраст не подходит
# Имя не подходит
# Не верный почтовый адрес
# Не достаточно аргументов
# Не верный почтовый адрес
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Не достаточно аргументов
# Имя не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# возраст не подходит
# Имя не подходит
# Имя не подходит
# возраст не подходит
